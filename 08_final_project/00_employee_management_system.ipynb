# %% [markdown]
# PROGRAM: Employee Management System
# AUTHOR: Sarosh Khan
# DATE: 04-Sep-2026
#
# PROBLEM:
# Write a Python program that manages employee records using all data types and operations learned.
#
# INPUT:
# - Hardcoded employee data (5 employees)
#
# OUTPUT:
# - Complete employee management system with:
#   1. Employee records display
#   2. Employee search
#   3. Employee add/update/delete
#   4. Department-wise summary
#   5. Salary statistics
#   6. All data types demonstration
#
# DATA TYPES COVERED:
# 1. str   - Name, Department, Position
# 2. int   - Employee ID, Age
# 3. float - Salary
# 4. list  - Projects, Skills
# 5. tuple - Address
# 6. range - Employee IDs
# 7. dict  - Employee Record
# 8. set   - Departments
# 9. frozenset - Fixed data
# 10. bool - Active Status
# 11. bytes - Encoded Name
# 12. bytearray - Modifiable Data
# 13. memoryview - Memory View
# 14. complex - (Optional) we will not use in this project

# %% [markdown]
# ============================================================
#        EMPLOYEE MANAGEMENT SYSTEM
# ============================================================
#
# ==================================================
# ALL EMPLOYEES
# ==================================================
#
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Developer
# Salary: 75000.50
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
# Employee ID: 102
# Name: Sara Khan
# Age: 25
# Department: HR
# Position: Recruiter
# Salary: 55000.00
# Projects: Recruitment 2024
# Skills: Communication, HR Software
# Active: True
#
# Employee ID: 103
# Name: Ahmed Raza
# Age: 30
# Department: IT
# Position: Team Lead
# Salary: 85000.00
# Projects: Project A, Project C, Project D
# Skills: Python, Java, Management
# Active: True
#
# Employee ID: 104
# Name: Fatima Noor
# Age: 27
# Department: Finance
# Position: Accountant
# Salary: 62000.00
# Projects: Financial Report 2024
# Skills: Excel, QuickBooks
# Active: True
#
# Employee ID: 105
# Name: Omar Farooq
# Age: 35
# Department: IT
# Position: System Admin
# Salary: 70000.00
# Projects: Network Setup, Security Audit
# Skills: Linux, Networking, Security
# Active: True
#
# ==================================================
# DEPARTMENT SUMMARY
# ==================================================
# IT: 3 employees, Avg Salary: 76666.83
# HR: 1 employees, Avg Salary: 55000.00
# Finance: 1 employees, Avg Salary: 62000.00
#
# ==================================================
# SALARY STATISTICS
# ==================================================
# Total Employees: 5
# Highest Salary: 85000.00
# Lowest Salary: 55000.00
# Average Salary: 69400.10
#
#  Employee 106 added successfully!
#
#  Employee 101 updated successfully!
#
# After Update:
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Senior Developer
# Salary: 80000.00
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
#  Employee 104 deleted successfully!
#
# After Delete:
# ==================================================
# ALL EMPLOYEES
# ==================================================
#
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Senior Developer
# Salary: 80000.00
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
# Employee ID: 102
# Name: Sara Khan
# Age: 25
# Department: HR
# Position: Recruiter
# Salary: 55000.00
# Projects: Recruitment 2024
# Skills: Communication, HR Software
# Active: True
#
# Employee ID: 103
# Name: Ahmed Raza
# Age: 30
# Department: IT
# Position: Team Lead
# Salary: 85000.00
# Projects: Project A, Project C, Project D
# Skills: Python, Java, Management
# Active: True
#
# Employee ID: 105
# Name: Omar Farooq
# Age: 35
# Department: IT
# Position: System Admin
# Salary: 70000.00
# Projects: Network Setup, Security Audit
# Skills: Linux, Networking, Security
# Active: True
#
# Employee ID: 106
# Name: Shakir Ali
# Age: 32
# Department: Marketing
# Position: Manager
# Salary: 65000.00
# Projects: Marketing Campaign 2024
# Skills: Marketing, Management
# Active: True
#
# ============================================================
#        ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!
# ============================================================

# %% [markdown]
# # Step 1: Problem Statement:
# ----------------------------
#
# ## what is the problem:
# We need to make an Employee Management System
#
# ## What is the input:
# -  Employee ID (number, must be unique)
# -  Name (text)
# -  Age  (number)
# -  Department (text like Developer, HR, IT, Finance)
# -  Position (text like Developer, Manager)
# -  Salary (Decimal numbers)
# -  Projects (list, can have many projects)
# -  Skills (list, can have many skils)
# -  Active_Status (True/False)
#
# ## What is the Output?
# 1. Show all employees details.
# 2. Show department wise count and average salaray
# 3. Show Salary statistics(highest, lowest, average and total)
# 4. Add  new employee with id 106
# 5. Update existing employee -> id 101
#    updated_values : Position -> Senior Developer, -> Slaray : 80000.00
# 6. delete employee with id -> 104
# 7. after delete again print the all emplyees list with updated data
#
# ## What are the Rules? (Conditions)
# - Employee ID must be unique (no duplicate)
# - Salary must be positive number
# - Age must be more than 18
# - Department and Position must be text
# - Active status must be True or False only

# %% [markdown]
# # Step 2: Requirements Analysis:
# --------------------------------
#
# ## 1. Tools We Need (Kya Tools Chahiye?):
#
# ### Programming Language:
#   -  python 3.x version
#
# ### Editor / Environment
#   - Jupitor Note Book easy to test code and execute cell by cell
#   - OR VS Code with Python extension
#
# ### Libraries (Python ke ready-made code)
# We will use only built-in Python (no extra library needed):
#  - print()` → output dikhane ke liye (to show output)
#  - len()` → length count karne ke liye (to count items)
#  - max()`, `min()`, `sum()` → calculations ke liye (for calculations)
#
# ### No External Library Required
#  - Hum koi pip install nahi kareng
#  - Sab kuch Python ke built-in features se hoga

# %% [markdown]
# # Step 2: Requirements Analysis:
# --------------------------------
#
# ## 2. Data We Need (Kya Data Chahiye?)
# --------------------------------------
# ### Data Type: Dictionary of Dictionaries (Nested Dictionary)
#
# ### Why Dictionary?
# - Employee ID unique hai (har employee ka alag ID hota hai)
# - Dictionary mein key = Employee ID (101, 102, etc.)
# - Value = us employee ki sari details
#
# ## Sample Data:
#
# ### Sample Data (5 Employees):
# | emp_id | name | age | department | position | salary |
# |--------|------|-----|------------|----------|--------|
# | 101 | Ali Ahmed | 28 | IT | Developer | 75000.50 |
# | 102 | Sara Khan | 25 | HR | Recruiter | 55000.00 |
# | 103 | Ahmed Raza | 30 | IT | Team Lead | 85000.00 |
# | 104 | Fatima Noor | 27 | Finance | Accountant | 62000.00 |
# | 105 | Omar Farooq | 35 | IT | System Admin | 70000.00 |
#
# ## Data Structure:
#
# employees = {
#     emp_id: {              # Key (unique number)
#         "name": "text",         # Employee ka naam
#         "age": number,          # Umar
#         "department": "text",   # Department (IT, HR, etc.)
#         "position": "text",     # Job title (Developer, Manager)
#         "salary": decimal,      # Tankhwah (with decimal point)
#         "projects": list,       # Projects ki list
#         "skills": list,         # Skills ki list
#         "is_active": bool       # True ya False
#     }
# }

# %% [markdown]
# # Step 2: Requirements Analysis:
# --------------------------------
#
# ## 3. Python Skills We Need (Kya Skills Chahiye?)
#
# ### Skill 1: Dictionary (Sabse Important)
#
# - Dictionary banana (creating)
# - Dictionary mein access karna (accessing values)
# - Dictionary mein add/update karna
# - Dictionary se delete karna
# - Dictionary pe loop chalana
#
# ## Examples:
#
# # Create dictionary
#
# student = {"name": "Ali",  "age":  20, }
#
# # Access the dictionary:
# print(student["name"]) # Output Ali:
#
# # Add the value
#   student["grade"] = "A"
#
# # Update the value
#   student["age"] = 21
#
# # Delete the value
#   del student["grade"]
#
# # For loop executation
#   for key, value in student.items():
#       print(key : value)
#
#  # Skill 2: For Loop
#    - iterate on items
#    - numbers = [1, 2, 3, 4, 5]
#      for num in numbers:
#           print(num) # Output: 1 2 3 4 5

# %% [markdown]
# Skill 3: List Comprehension (Shortcut):
#
# Create a list in one line:
#
# numbers = [1, 2, 3, 4, 5]
#
# squares = [x * x for  x in  numbers]
# print(squares)  # Output: [1, 4, 9, 16, 25]

# %% [markdown]
# Skill 4: Functions:
# -------------------
#
# -  Reusable code banana
# -  def keyward use karna
# -  parameters or return
#
# Example:
#
# def greet(name):
#     return f "Hello {name}"
#
# print(greet("Ali"))
#
# Skill 5: String Formatting (f-string)
#
# Variables ko string mein daaln
#
# name = "Ali"
#
# age = 20
#
# name = "Ali"
# print(f"My name is {name}")

# %% [markdown]
# Skill 5: Conditional Statements (if/else)
#
# age = 18
# if age >= 18:
#    print("Adult)
# else:
#    print("Minor")

# %% [markdown]
# **kwargs Concept:  (Keyward Argument)
# -----------------
#
# **kwargs Kya Hai?
#
# **kwargs = "Keyword Arguments"
#
# Function mein multiple optional parameters dene ka tareeqa. Aap function call karte waqt jitne chahein utne parameters de sakte ho.
# Function banane mein hum pehle se nahi jaante ke kitne parameters aayenge. **kwargs se user jitne chahein utne parameters pass kar sakta hai.
#
# Example:
# --------
#
# Problem Kya Hai Pehle?:
#
# Normal Function:
#
# def update_employee(name, age, salaray):
#     print(f"Name : {name}, {age}, {salary}")
#
#     # Ab sirf name update karna ho?
#     update_employee("Ali") error: ERROR! age aur salary bhi dena padega
#
# Problem: Function mein fixed parameters hain. Agar sirf 1 cheez update karni ho toh bhi sab dena padega.
#
# **kwargs Solution:
#
#   def update_employee(**kwargs):
#       for key, value in kwargs.items()
#       print(f"{key} : {value}")
#
#  # Ab jitne chahein utne parameters de sakte ho!
#    update_employee(name="Ali")
#   # Output: name: Ali
#
#  update_employee(name="Ali", age=20)
# # Output: name: Ali, age: 20
#
# update_employee(name="Ali", age=20, salary=50000, position="Developer")
# # Output: name: Ali, age: 20, salary: 50000, position: Developer

# %% [markdown]
# # Step 3: Algorithm Design:
#
#   ## What is Algorithm?
# -  step by step plan
# -  to solve a specific problem
# -  written in a simple english
#
#  ## why we need Algorithm before coding?
#
#  - to think before coding
#  - to clear the logic
#  - to avoid mistakes
#  - to save time

# %% [markdown]
# ##  Step 3 Algorithm Design:
# -----------------------------
#
# ## Algorithm 1: Display All Employees:
#
# ### purpose:
# - show all employees details.
#
#
# ### Input:
# - employees dictionary (already has data)
#
#
# ### Output:
# - print the all employees details on the screen.
#
#
# ### steps:
#
# 1. Start
# 2. Print the header
# 3. For each employees in employees:
#    -get employee id
#    -get employee info
#    -print all details (name, age, dept, etc)
# 4. -End

# %% [markdown]
# ##  Step 3: Algorithm Design:
#
# ## Alogorithm 2 Department wise summary:
# -----------------------------------------
#
# ### Purpose:
# ------------
# - Show department wise count.
# - Show average salary department wise.
#
# ### Input:
# ----------
# - employess dictionary (with all employee data)
#
#
# ### output:
# -----------
# - each department name with employees count and average salary
#
#
# ### steps:
# ----------
#
# 1. Start
# 2. Take a blank notebook (dept_data {})
# 3. For each employee in employees:
#    - get dept_name and dept_salary
#    - check department in the notebook?
#      - if Not in notebook:
#      - create new entry with count = 0 , and salary = 0
#      - add 1 to count
#      - add salary to total salary
#
# 4. For each department in notebook:
#    -calculate average_salary = total_salary / count
#    -print department, count, average_salary
# 5. -End
#
# ## Algorithm 3: SALARY STATISTICS:
# ----------------------------------
#
# ### Purpose:
# - Show salary statistics of all employees
# - Display: total count, highest, lowest, average salary
#
# ### Input:
# - Already available in the employees dictionary
#
# ### Output:
# 1. Total Employees: 5
# 2. Highest Salary: 85000.00
# 3. Lowest Salary: 55000.00
# 4. Average Salary: 69400.10
# 5. Formatted output with header
#
# ### Steps:
# 1. Start
# 2. Print separator line
# 3. Print header "SALARY STATISTICS"
# 4. Get all salaries from employees
# 5. Calculate total using sum()
# 6. Calculate count using len()
# 7. Find highest using max()
# 8. Find lowest using min()
# 9. Calculate average = total / count
# 10. Print all values
# 11. End
#
# ## Algorithm 4   Add 106 :
# --------------------------
# ### Purpose:
# - Add  a new employee in the system
# - Check for duplicate ID before adding
#
# ### Input:
# - Employee ID: 106
# - Name: Shakir Khan
# - Department: Data Science
# - Salary: 70000.00
# - Projects: [Chatbot, Dashboard]
# - Skills: [Python, DSA, Prompt Eng]
# - Active: True
#
#
# ### Output:
# - Success message: "Employee 106 added successfully!"
# - OR Error message: "Employee already exists!"
#
# ### Steps:
# 1. Start
# 2. Get employees details (id, name, dept, salary, projects, skills)
# 3. Check if employee_id already exist in emplyees?
# 4. If not exist "Add" new employee
#    -Add new employee to employee dictionary
#    -Print "Employee added successfully!"
#
# 5. Else:
#    - (Already exist error case)
#    - Print Employee already exist!.
#    - Do not add
# 6. End
#
#
# ## Algorithm 5: Update Employee ID 101
#
# ### Purpose:
#
# -I have update an existing emplyee 101 with  data -> salary and position
#
# ### Input:
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Senior Developer
# Salary: 80000.00
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
#
# ## Output:
# -1 After Update Employee 101 updated successfully!
# -2 print the all detils again with updated data
#
# ## Steps:
#
# 1. Start
# 2. employees ['101']['Position'] = 'Senior Developer'
# 3. employees ['101']['Salary'] = 80000.00
#
# End
#
# ## Algorithm 6: delete 104
#
# ### Purpose:
#
# I have to delete the ID 104 from the system
#
# ### Input:
# Employee ID: 104
# Name: Fatima Noor
# Age: 27
# Department: Finance
# Position: Accountant
# Salary: 62000.00
# Projects: Financial Report 2024
# Skills: Excel, QuickBooks
# Active: True
#
# ### Output:
# Employee 104 deleted successfully!
#
# After Delete:
#
# ==================================================
# ALL EMPLOYEES
# ==================================================
#
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Senior Developer
# Salary: 80000.00
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
# Employee ID: 102
# Name: Sara Khan
# Age: 25
# Department: HR
# Position: Recruiter
# Salary: 55000.00
# Projects: Recruitment 2024
# Skills: Communication, HR Software
# Active: True
#
# Employee ID: 103
# Name: Ahmed Raza
# Age: 30
# Department: IT
# Position: Team Lead
# Salary: 85000.00
# Projects: Project A, Project C, Project D
# Skills: Python, Java, Management
# Active: True
#
# Employee ID: 105
# Name: Omar Farooq
# Age: 35
# Department: IT
# Position: System Admin
# Salary: 70000.00
# Projects: Network Setup, Security Audit
# Skills: Linux, Networking, Security
# Active: True
#
# Employee ID: 106
# Name: Shakir Ali
# Age: 32
# Department: Marketing
# Position: Manager
# Salary: 65000.00
# Projects: Marketing Campaign 2024
# Skills: Marketing, Management
# Active: True
#
# ============================================================
#        ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!
# ============================================================
#
#
# ### steps:
#
# 1. start
# 2. Check 104 exist in the employee list?
# -  if 104 in employees:
# -  del['104']
#    print(f"Employee 104 deleted successfully!")
#    else:
#    print(f"employee does not exist in the system")
#
#
# 3. print statement: "After Delete:"
#
# 4. for employee in employees:
#        print(key)
#    for inner_key, inner_value in employee.items()
#        print(f"{inner_key} : {inner_values}")
#
# 5.print
# ============================================================
#        ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!
# ============================================================
#
# End

# %% [markdown]
# # Employee Management System - Complete Algorithm Design
#
# ## Project Overview
# A comprehensive system to manage employee data with CRUD operations, statistical analysis, and reporting capabilities.
#
# ---
#
# ## Algorithm 1: Display All Employees
#
# ### Purpose:
# - Display complete details of all employees in a structured format
# - Provide clear visibility of workforce data
#
# ### Input:
# - Pre-loaded employees dictionary containing employee records
#
# ### Output:
# - Formatted display of all employees with their complete information
#
# ### Steps:
# 1. Start
# 2. Print separator line for visual clarity
# 3. Print header "ALL EMPLOYEES"
# 4. Print separator line
# 5. For each employee_id and employee_info in employees dictionary:
#    a. Print blank line for spacing
#    b. Print "Employee ID: " followed by employee_id
#    c. Print "Name: " followed by employee name
#    d. Print "Age: " followed by employee age
#    e. Print "Department: " followed by department name
#    f. Print "Position: " followed by job position
#    g. Print "Salary: " followed by formatted salary
#    h. Print "Projects: " followed by project list
#    i. Print "Skills: " followed by skills list
#    j. Print "Active: " followed by active status
# 6. End
#
# ---
#
# ## Algorithm 2: Department Summary
#
# ### Purpose:
# - Calculate and display employee count per department
# - Calculate average salary for each department
# - Provide department-wise workforce insights
#
# ### Input:
# - Employees dictionary with department and salary information
#
# ### Output:
# - Department name with employee count and average salary
#
# ### Steps:
# 1. Start
# 2. Print header "DEPARTMENT SUMMARY"
# 3. Create empty dictionary named dept_data
# 4. For each employee in employees:
#    a. Extract department name
#    b. If department not in dept_data:
#       - Initialize department with count=0 and total_salary=0
#    c. Increment count by 1
#    d. Add employee salary to total_salary
# 5. For each department in dept_data:
#    a. Calculate average salary = total_salary divided by count
#    b. Print department name, count, and average salary
# 6. End
#
# ---
#
# ## Algorithm 3: Salary Statistics
#
# ### Purpose:
# - Display comprehensive salary statistics across the organization
# - Provide insights into highest, lowest, and average compensation
# - Show total workforce size
#
# ### Input:
# - Employees dictionary containing salary data
#
# ### Output:
# - Total employee count
# - Highest salary in organization
# - Lowest salary in organization
# - Average salary calculation
#
# ### Steps:
# 1. Start
# 2. Print header "SALARY STATISTICS"
# 3. Create empty list named all_salaries
# 4. For each employee in employees:
#    a. Extract salary value
#    b. Append salary to all_salaries list
# 5. Calculate total_employees = length of all_salaries
# 6. Calculate highest_salary = maximum value from all_salaries
# 7. Calculate lowest_salary = minimum value from all_salaries
# 8. Calculate average_salary = sum of all_salaries divided by total_employees
# 9. Print total_employees
# 10. Print highest_salary formatted to 2 decimal places
# 11. Print lowest_salary formatted to 2 decimal places
# 12. Print average_salary formatted to 2 decimal places
# 13. End
#
# ---
#
# ## Algorithm 4: Add New Employee
#
# ### Purpose:
# - Add a new employee record to the system
# - Validate data to prevent duplicate entries
# - Ensure data integrity through input validation
#
# ### Input:
# - Employee ID (unique identifier)
# - Name (string)
# - Age (integer, must be 18 or above)
# - Department (string)
# - Position (string)
# - Salary (numeric, must be positive)
# - Projects (list)
# - Skills (list)
# - Active status (boolean)
#
# ### Output:
# - Success message: "Employee added successfully!"
# - OR Error message: "Employee already exists!"
#
# ### Steps:
# 1. Start
# 2. Receive all employee details as input
# 3. Check if employee ID already exists in employees dictionary
# 4. If employee ID does NOT exist:
#    a. Add new employee record to employees dictionary
#    b. Print "Employee added successfully!"
# 5. Else (employee ID already exists):
#    a. Print "Error: Employee already exists!"
#    b. Do not add duplicate record
# 6. End
#
# ---
#
# ## Algorithm 5: Update Employee
#
# ### Purpose:
# - Modify existing employee information
# - Update specific fields without affecting other data
# - Provide flexible update mechanism for any employee attribute
#
# ### Input:
# - Employee ID (target employee)
# - Field names and new values to update (using **kwargs for flexibility)
#
# ### Output:
# - Success message: "Employee updated successfully!"
# - Display of all updated employee details
# - OR Error message if employee not found
#
# ### Steps:
# 1. Start
# 2. Get employee ID and fields to update
# 3. Check if employee ID exists in employees dictionary
# 4. If employee ID exists:
#    a. For each field and new_value in update parameters:
#       - If field exists in employee record:
#         * Update field with new value
#         * Print "Updated: field_name"
#       - Else:
#         * Print "Field does not exist, skipping"
#    b. Print "Employee updated successfully!"
#    c. Display all updated employee details
# 5. Else (employee ID not found):
#    a. Print "Error: Employee not found!"
# 6. End
#
# ---
#
# ## Algorithm 6: Delete Employee
#
# ### Purpose:
# - Remove an employee record from the system
# - Verify employee exists before deletion
# - Display updated employee list after deletion
#
# ### Input:
# - Employee ID (to be deleted)
#
# ### Output:
# - Success message: "Employee deleted successfully!"
# - Complete list of remaining employees
# - Final success message: "ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!"
# - OR Error message if employee not found
#
# ### Steps:
# 1. Start
# 2. Get employee ID to delete
# 3. Check if employee ID exists in employees dictionary
# 4. If employee ID exists:
#    a. Delete employee record using del keyword
#    b. Print "Employee deleted successfully!"
# 5. Else (employee ID not found):
#    a. Print "Error: Employee does not exist!"
# 6. Print "After Delete:" header
# 7. For each remaining employee in employees:
#    a. Display complete employee details
# 8. Print "ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!"
# 9. End
#
# ---
#
# ## Main Program Execution Flow
#
# ### Purpose:
# - Orchestrate all algorithms in proper sequence
# - Demonstrate complete system functionality
#
# ### Steps:
# 1. Initialize employees dictionary with 5 predefined employee records
# 2. Display welcome message
# 3. Execute Algorithm 1: Display all initial employees
# 4. Execute Algorithm 2: Show department summary
# 5. Execute Algorithm 3: Display salary statistics
# 6. Execute Algorithm 4: Add new employee (ID 106)
# 7. Execute Algorithm 5: Update employee (ID 101 - promote to Senior Developer)
# 8. Execute Algorithm 6: Delete employee (ID 104)
# 9. Display final employee list
# 10. Print completion message
# 11. End
#
# ---
#
# ## Key Concepts Demonstrated
#
# - Dictionary data structure for efficient data storage and retrieval
# - For loops for iteration over dictionary items
# - Conditional statements (if/else) for decision making
# - List operations (append, iteration)
# - Built-in functions (max, min, sum, len)
# - String formatting with f-strings
# - CRUD operations (Create, Read, Update, Delete)
# - Data validation and error handling
# - Nested data structures
# - Function-based modular design

# %%
# ============================================================
# PROGRAM: Employee Management System
# AUTHOR : Sarosh Khan
# DATE   : 04-Sep-2026
#
# PROBLEM:
#   Write a Python program that manages employee records
#   using all data types and operations learned.
#
# DATA TYPES COVERED:
#   1. str        -> Name, Department, Position
#   2. int        -> Employee ID, Age
#   3. float      -> Salary
#   4. list       -> Projects, Skills
#   5. tuple      -> Allowed Departments (fixed data)
#   6. range      -> Valid Employee ID range
#   7. dict       -> Employee Record (nested dictionary)
#   8. set        -> Unique Departments
#   9. frozenset  -> Company Benefits (fixed data)
#  10. bool       -> Active Status
#  11. bytes      -> Encoded Names
#  12. bytearray  -> Modifiable Registry Buffer
#  13. memoryview -> Memory View of the Registry
#  14. complex    -> (Optional) not used in this project
# ============================================================

# ============================================================
# Step 2: DATA - Nested Dictionary (Dictionary of Dictionaries)
#   Key   = Employee ID (unique number)
#   Value = Dictionary with all employee details
# ============================================================

employees = {
    101: {
        "name": "Ali Ahmed",
        "age": 28,
        "department": "IT",
        "position": "Developer",
        "salary": 75000.50,
        "projects": ["Project A", "Project B"],
        "skills": ["Python", "SQL"],
        "is_active": True,
    },
    102: {
        "name": "Sara Khan",
        "age": 25,
        "department": "HR",
        "position": "Recruiter",
        "salary": 55000.00,
        "projects": ["Recruitment 2024"],
        "skills": ["Communication", "HR Software"],
        "is_active": True,
    },
    103: {
        "name": "Ahmed Raza",
        "age": 30,
        "department": "IT",
        "position": "Team Lead",
        "salary": 85000.00,
        "projects": ["Project A", "Project C", "Project D"],
        "skills": ["Python", "Java", "Management"],
        "is_active": True,
    },
    104: {
        "name": "Fatima Noor",
        "age": 27,
        "department": "Finance",
        "position": "Accountant",
        "salary": 62000.00,
        "projects": ["Financial Report 2024"],
        "skills": ["Excel", "QuickBooks"],
        "is_active": True,
    },
    105: {
        "name": "Omar Farooq",
        "age": 35,
        "department": "IT",
        "position": "System Admin",
        "salary": 70000.00,
        "projects": ["Network Setup", "Security Audit"],
        "skills": ["Linux", "Networking", "Security"],
        "is_active": True,
    },
}

# ============================================================
# ALL REMAINING DATA TYPES USED INSIDE THE SYSTEM
# ============================================================

# 5. tuple : non-changing / fixed data
ALLOWED_DEPARTMENTS = ("IT", "HR", "Finance", "Marketing", "Data Science")

# 9. frozenset : fixed company benefits (cannot be changed)
COMPANY_BENEFITS = frozenset({"Health Insurance", "Bonus", "Paid Leave"})

# 8. set : unique departments collected from the employees dictionary
unique_departments = {emp["department"] for emp in employees.values()}

# 6. range : valid employee ID range
EMPLOYEE_ID_RANGE = range(100, 200)

# 11/12/13. bytes + bytearray + memoryview : registry buffer
registry_buffer = bytearray()                       # bytearray (modifiable)
for emp in employees.values():
    registry_buffer.extend(emp["name"].encode("utf-8"))   # bytes (encoded)
registry_view = memoryview(registry_buffer)         # memoryview (no copy)

def validate_employee_data(emp_id, age, salary, department):
    """Check that new employee data follows the project rules."""
    valid_id = emp_id in EMPLOYEE_ID_RANGE          # range membership test
    valid_age = age > 18                            # age must be > 18
    valid_salary = salary > 0                       # salary must be positive
    valid_dept = department in ALLOWED_DEPARTMENTS  # tuple membership test
    return valid_id and valid_age and valid_salary and valid_dept
# ============================================================
# ALGORITHM 1: DISPLAY ALL EMPLOYEES
# ============================================================

def display_employee(emp_id, emp):
    """Print one employee's complete details."""
    print(f"Employee ID: {emp_id}")
    print(f"Name: {emp['name']}")
    print(f"Age: {emp['age']}")
    print(f"Department: {emp['department']}")
    print(f"Position: {emp['position']}")
    print(f"Salary: {emp['salary']:.2f}")
    print(f"Projects: {', '.join(emp['projects'])}")
    print(f"Skills: {', '.join(emp['skills'])}")
    print(f"Active: {emp['is_active']}")
    print()

def display_all_employees(employees):
    """Show the complete list of all employees."""
    print("=" * 50)
    print("ALL EMPLOYEES")
    print("=" * 50)
    print()
    for emp_id, emp in employees.items():
        display_employee(emp_id, emp)

# ============================================================
# ALGORITHM 2: DEPARTMENT-WISE SUMMARY
# ============================================================

def department_summary(employees):
    """Show employee count and average salary per department."""
    print("=" * 50)
    print("DEPARTMENT SUMMARY")
    print("=" * 50)

    dept_data = {}
    for emp in employees.values():
        dept = emp["department"]
        if dept not in dept_data:
            dept_data[dept] = {"count": 0, "total_salary": 0.0}
        dept_data[dept]["count"] += 1
        dept_data[dept]["total_salary"] += emp["salary"]

    for dept, data in dept_data.items():
        avg_salary = data["total_salary"] / data["count"]
        print(f"{dept}: {data['count']} employees, Avg Salary: {avg_salary:.2f}")
    print()

# ============================================================
# ALGORITHM 3: SALARY STATISTICS
# ============================================================

def salary_statistics(employees):
    """Show total, highest, lowest and average salary."""
    print("=" * 50)
    print("SALARY STATISTICS")
    print("=" * 50)

    all_salaries = []
    for emp in employees.values():
        all_salaries.append(emp["salary"])

    total_employees = len(all_salaries)
    highest_salary = max(all_salaries)
    lowest_salary = min(all_salaries)
    average_salary = sum(all_salaries) / total_employees

    print(f"Total Employees: {total_employees}")
    print(f"Highest Salary: {highest_salary:.2f}")
    print(f"Lowest Salary: {lowest_salary:.2f}")
    print(f"Average Salary: {average_salary:.2f}")
    print()

# ============================================================
# ALGORITHM 4: ADD NEW EMPLOYEE
# ============================================================

def add_employee(employees, emp_id, name, age, department, position,
                 salary, projects, skills, is_active=True):
    """Add a new employee after checking for duplicate ID."""
    if emp_id in employees:
        print("Error: Employee already exists!")
        return

    employees[emp_id] = {
        "name": name,
        "age": age,
        "department": department,
        "position": position,
        "salary": salary,
        "projects": projects,
        "skills": skills,
        "is_active": is_active,
    }
    print(f" Employee {emp_id} added successfully!")
    print()

# ============================================================
# ALGORITHM 5: UPDATE EMPLOYEE  (uses **kwargs)
# ============================================================

def update_employee(employees, emp_id, **kwargs):
    """Update one or more fields of an existing employee."""
    if emp_id not in employees:
        print("Error: Employee not found!")
        return

    for field, new_value in kwargs.items():
        if field in employees[emp_id]:
            employees[emp_id][field] = new_value
        else:
            print(f"Field does not exist, skipping: {field}")

    print(f" Employee {emp_id} updated successfully!")
    print()
    print("After Update:")
    display_employee(emp_id, employees[emp_id])

# ============================================================
# ALGORITHM 6: DELETE EMPLOYEE
# ============================================================

def delete_employee(employees, emp_id):
    """Delete an employee and print the remaining employee list."""
    if emp_id in employees:
        del employees[emp_id]
        print(f" Employee {emp_id} deleted successfully!")
        print()
    else:
        print("Error: Employee does not exist!")

    print("After Delete:")
    display_all_employees(employees)
# ============================================================
# MAIN PROGRAM EXECUTION FLOW
# ============================================================

# Welcome banner
print("=" * 60)
print("       EMPLOYEE MANAGEMENT SYSTEM")
print("=" * 60)
print()

# 1. Display all initial employees
display_all_employees(employees)

# 2. Show department-wise summary
department_summary(employees)

# 3. Show salary statistics
salary_statistics(employees)

# 4. Add new employee -> ID 106
add_employee(
    employees,
    emp_id=106,
    name="Shakir Ali",
    age=32,
    department="Marketing",
    position="Manager",
    salary=65000.00,
    projects=["Marketing Campaign 2024"],
    skills=["Marketing", "Management"],
    is_active=True,
)

# 5. Update employee -> ID 101 (promote position and salary)
update_employee(employees, 101, position="Senior Developer", salary=80000.00)

# 6. Delete employee -> ID 104
delete_employee(employees, 104)

# Final completion message
print("=" * 60)
print("       ALL CONCEPTS DEMONSTRATED SUCCESSFULLY!")
print("=" * 60)
# Out:
# ...
#        EMPLOYEE MANAGEMENT SYSTEM
# ...
#
# ...
# ALL EMPLOYEES
# ...
#
# Employee ID: 101
# Name: Ali Ahmed
# Age: 28
# Department: IT
# Position: Developer
# Salary: 75000.50
# Projects: Project A, Project B
# Skills: Python, SQL
# Active: True
#
# Employee ID: 102
# Name: Sara Khan
# Age: 25
# Department: HR
# Position: Recruiter
# Salary: 55000.00
# Projects: Recruitment 2024
# Skills: Communication, HR Software
# Active: True
#
# Employee ID: 103
# Name: Ahmed Raza
# Age: 30
# Department: IT
# Position: Team Lead
# Salary: 85000.00
# Projects: Project A, Project C, Project D
# Skills: Python, Java, Management
# Active: True
#
# Employee ID: 104
# Name: Fatima Noor
# Age: 27
# Department: Finance
# Position: Accountant
# Salary: 62000.00
# Projects: Financial Report 2024
# Skills: Excel, QuickBooks
# Active: True
#
# Employee ID: 105
# Name: Omar Farooq
# Age: 35
# Department: IT
# Position: System Admin
# Salary: 70000.00
# Projects: Network Setup, Security Audit
# ...
