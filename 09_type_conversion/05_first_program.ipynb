# %%
# print my name:

print("Hello Sarosh")
# Out:
# Hello Sarosh

# %%
# print Indian AI production

print("You are started Learning Python for Agentic AI Engineering ")
# Out:
# You are started Learning Python for Agentic AI Engineering

# %%
# print greeting message

print("Welcome in Agentic AI Course!")
# Out:
# Welcome in Agentic AI Course!
