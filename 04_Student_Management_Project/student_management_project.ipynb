# %% [markdown]
# Problem Statement:
# ------------------
# Write a Python program that manages student records using all 14 data types.
# The program should store, display, and manipulate student information.
#
# Input: None (Hardcoded values)
#
# Output: Complete student profile with all 14 data types
#
# Data Types to Cover:
# 1. str   2. int   3. float   4. list
# 5. tuple  6. range  7. dict   8. set
# 9. frozenset  10. bool  11. bytes
# 12. bytearray  13. memoryview  14. complex

# %% [markdown]
# Problem-Solving-Steps:
# ----------------------
#
# Step 1: Problem Statement:
#
# *Understand the Problem Completly:
#
# I need to write a python Program that manage student records including all 14 data-types
# and the program should store, display, & manipulate student information.
#
# *Input Required:
# None: -> Only Hardcoded values
#
# *Output Required:
# ================================================================================
#                     STUDENT MANAGEMENT SYSTEM
#                     All 14 Data Types Demonstration
# ================================================================================
#
# 1. String (str):
#    Name     : Ali Ahmed
#    City     : Karachi
#
# 2. Integer (int):
#    Roll No  : 101
#    Age      : 22
#
# 3. Float (float):
#    GPA      : 3.75
#
# 4. List (list):
#    Subjects : ['Math', 'Physics', 'CS', 'English']
#    Grades   : [85, 90, 88, 78]
#
# 5. Tuple (tuple):
#    Address  : ('House 10', 'Street 5', 'Karachi', 'Pakistan')
#
# 6. Range (range):
#    Student IDs: [101, 102, 103, 104, 105]
#
# 7. Dictionary (dict):
#    Student Record: {'name': 'Ali Ahmed', 'roll_no': 101, 'age': 22, ...}
#
# 8. Set (set):
#    Courses  : {'Data Science', 'AI', 'Python', 'Machine Learning'}
#
# 9. Frozenset (frozenset):
#    Fixed Data: frozenset({'Batch: 2024', 'Section: A', 'Student ID: 101'})
#
# 10. Boolean (bool):
#     Active   : True
#     Graduated: False
#
# 11. Bytes (bytes):
#     Encoded Name: b'Ali Ahmed'
#
# 12. Bytearray (bytearray):
#     Modifiable Data: bytearray(b'Learner Data')
#
# 13. Memoryview (memoryview):
#     Memory View: <memory at 0x...>
#
# 14. Complex (complex):
#     (Optional) Complex: 3+4j
#
# ================================================================================
#                     COMPLETE STUDENT PROFILE
# ================================================================================
#
# Name           : Ali Ahmed
# Roll No        : 101
# Age            : 22
# City           : Karachi
# GPA            : 3.75
# Subjects       : Math, Physics, Computer Science, English
# Grades         : [85, 90, 88, 78]
# Average Grade  : 85.25
# Address        : House 10, Street 5, Karachi, Pakistan
# Active Status  : True
# Courses        : Data Science, AI, Python, Machine Learning
# Encoded Name   : b'Ali Ahmed'
#
# ================================================================================
#                     ALL 14 DATA TYPES DEMONSTRATED SUCCESSFULLY!
# ================================================================================
#
# Conditions Required:
# --------------------
#
# CONDITIONS:
# -----------
# 1. Use all 14 data types in a meaningful way
# 2. Display each data type with its value and type
# 3. Show type conversion where applicable
# 4. Clean, professional output formatting
# 5. Well-commented code for readability

# %% [markdown]
# Step 2: Requirements Analysis:
# ================================================================================
#
# Tools Required:
# ---------------
# - VS Code / Jupyter Notebook
# - Python 3.x (or latest version)
# - Git (for version control)
#
# Data Required:
# --------------
# | # | Data Type | Purpose |
# |---|-----------|---------|
# | 1 | str | Name, City, Address components |
# | 2 | int | Roll No, Age, Grades |
# | 3 | float | GPA |
# | 4 | list | Subjects, Grades list |
# | 5 | tuple | Address (immutable) |
# | 6 | range | Student ID range |
# | 7 | dict | Complete student record |
# | 8 | set | Unique courses |
# | 9 | frozenset | Fixed data (Batch, Section) |
# | 10 | bool | Active status, Graduation status |
# | 11 | bytes | Encoded name (security) |
# | 12 | bytearray | Modifiable data |
# | 13 | memoryview | Memory efficient view |
#
# Note: Complex number is NOT required for this project.
#
# Skills Required:
# ----------------
# 1. Create variables with correct data types
# 2. Store appropriate values in each data type
# 3. Use print() function to display values with their types
# 4. Manipulate data (type conversion where needed)
# 5. Use f-strings for formatted output
# 6. Create professional output formatting
# 7. Write clean, well-commented code
#
# Libraries Required:
# -------------------
# - None (All built-in Python functions)

# %% [markdown]
# Step 3: Algorithm Design:
#
# Step-by-step Logical Flow:
#
# Program Start:
#
# 1. PRINT header:
#    "STUDENT MANAGEMENT SYSTEM"
#    "All 14 Data Types Demonstration"
#
# 2. CREATE Variables with data types:
#
#    str:
#    name = "Ali Ahmed"
#
#    int:
#    age = 22
#    roll_number = 101
#
#    float:
#    gpa = 3.77
#
#    list:
#    subjects = ['Math', 'Physics', 'CS', 'English']
#    grades = [85, 90, 88, 78]
#
#    tuple:
#    address = ('House 10', 'Street 5', 'Karachi', 'Pakistan')
#
#    range:
#    student_ids = range(101, 106)   # 101,102,103,104,105
#
#    dict:
#    student_record = {
#        "name": "Ali Ahmed",
#        "roll_num": 101,
#        "age": 22
#    }
#
#    set:
#    courses = {'Data Science', 'AI', 'Python', 'Machine Learning'}
#
#    frozenset:
#    batch_num = frozenset({'Batch: 2024', 'Section A', 'Student_ID: 101'})
#
#    bool:
#    is_student = True
#    is_graduated = False
#
#    bytes:
#    encoded_name = b'Ali Ahmed'
#
#    bytearray:
#    bytearr_mod = bytearray(b'Learning Python')
#
#    memoryview:
#    student_name_bytes = memoryview(encoded_name)
#
# 3. PRINT "COMPLETE STUDENT PROFILE"
#
# 4. PRINT all student information:
#    - Name      : Ali Ahmed
#    - Age       : 22
#    - City      : Karachi
#    - GPA       : 3.75
#    - Subjects  : Math, Physics, Computer Science, English
#    - Grades    : 85, 90, 88, 78
#    - Average   : sum(grades) / len(grades)
#    - Address   : House 10, Street 5, Karachi, Pakistan
#    - Active    : True
#
# 5. PRINT footer:
#    "All 14 Data Types DEMONSTRATED SUCCESSFULLY!"
#
# END

# %% [markdown]
# PROGRAM: Student Management System
# AUTHOR: Sarosh Khan
# DATE: 02-Sep-2026
#
# BEGIN
#
#     // ============================================
#     // STEP 1: HEADER
#     // ============================================
#
#     PRINT "=" * 60
#     PRINT "STUDENT MANAGEMENT SYSTEM"
#     PRINT "All 14 Data Types Demonstration"
#     PRINT "=" * 60
#
#     // ============================================
#     // STEP 2: CREATE VARIABLES
#     // ============================================
#
#     // String
#     CREATE name = "Ali Ahmed"
#     CREATE city = "Karachi"
#
#     // Integer
#     CREATE age = 22
#     CREATE roll_number = 101
#
#     // Float
#     CREATE gpa = 3.77
#
#     // List
#     CREATE subjects = ["Math", "Physics", "CS", "English"]
#     CREATE grades = [85, 90, 88, 78]
#
#     // Tuple
#     CREATE address = ("House 10", "Street 5", "Karachi", "Pakistan")
#
#     // Range
#     CREATE student_ids = range(101, 106)
#
#     // Dictionary
#     CREATE student_record = {
#         "name": "Ali Ahmed",
#         "roll_num": 101,
#         "age": 22
#     }
#
#     // Set
#     CREATE courses = {"Data Science", "AI", "Python", "Machine Learning"}
#
#     // Frozenset
#     CREATE batch_num = frozenset({"Batch: 2024", "Section A", "Student_ID: 101"})
#
#     // Boolean
#     CREATE is_student = True
#     CREATE is_graduated = False
#
#     // Bytes
#     CREATE encoded_name = b'Ali Ahmed'
#
#     // Bytearray
#     CREATE bytearr_mod = bytearray(b'Learning Python')
#
#     // Memoryview
#     CREATE student_name_bytes = memoryview(encoded_name)
#
#     // ============================================
#     // STEP 3: DISPLAY STUDENT PROFILE
#     // ============================================
#
#     PRINT "COMPLETE STUDENT PROFILE"
#     PRINT "=" * 60
#
#     PRINT "Name      :", name
#     PRINT "Age       :", age
#     PRINT "City      :", city
#     PRINT "GPA       :", gpa
#     PRINT "Subjects  :", subjects
#     PRINT "Grades    :", grades
#
#     // Calculate average
#     average = sum(grades) / len(grades)
#     PRINT "Average   :", average
#
#     PRINT "Address   :", address
#     PRINT "Active    :", is_student
#
#     // ============================================
#     // STEP 4: DISPLAY ALL DATA TYPES WITH TYPES
#     // ============================================
#
#     PRINT "All 14 Data Types Demonstration:"
#     PRINT "str        :", name, "->", TYPE(name)
#     PRINT "int        :", age, "->", TYPE(age)
#     PRINT "float      :", gpa, "->", TYPE(gpa)
#     PRINT "list       :", subjects, "->", TYPE(subjects)
#     PRINT "tuple      :", address, "->", TYPE(address)
#     PRINT "range      :", student_ids, "->", TYPE(student_ids)
#     PRINT "dict       :", student_record, "->", TYPE(student_record)
#     PRINT "set        :", courses, "->", TYPE(courses)
#     PRINT "frozenset  :", batch_num, "->", TYPE(batch_num)
#     PRINT "bool       :", is_student, "->", TYPE(is_student)
#     PRINT "bytes      :", encoded_name, "->", TYPE(encoded_name)
#     PRINT "bytearray  :", bytearr_mod, "->", TYPE(bytearr_mod)
#     PRINT "memoryview :", student_name_bytes, "->", TYPE(student_name_bytes)
#
#     // ============================================
#     // STEP 5: FOOTER
#     // ============================================
#
#     PRINT "=" * 60
#     PRINT "All 14 Data Types DEMONSTRATED SUCCESSFULLY!"
#     PRINT "=" * 60
#
# END

# %%
#step 1: Print Header:

print("\n" + "="  * 60)

print("\n...................STUDENT MANAGEMENT SYSTEM\n...................ALL 14 DATATYPES")
# Out:
# ...
#
# ...................STUDENT MANAGEMENT SYSTEM
# ...................ALL 14 DATATYPES

# %%
#step 2: Create variables 13 variables of different data types:

name = "Ahmed Ali" # string

age  = 22 # integer

roll_number = 101  # integer

gpa = 3.75  # float

subjects = ['Math', 'Physics', 'CS', 'English'] # list
grades   = [85, 90, 88, 78] #list

Address = ('House 10',  'Street 5', 'Karachi', 'Pakistan') # tuple immutable

student_record = {'name': 'Ali Ahmed', 'age': 22,  'roll_number' : 101, 'gpa' : 3.75,} # dictionary

student_Ids = (101, 106) # range

courses = {'Data Science', 'Machine Learning', 'AI', 'Python'} # ste

fixed_data = frozenset({'Batch : 2024', 'Section : A', 'Student_ID : 101'}) # frozenset

is_active = True # boolean
is_graduated = False # boolean

encoded_name = b'Ali Ahmed' # bytes

modified_data = bytearray(b'Learner Data') # bytearray

memory_data = memoryview(encoded_name) # memoryview

# %%
#step 3: print the all data-types and its values:

print("\n" + "="  * 60)
print("\n...................STUDENT COMPLETE PROFILE")
print("\n" + "="  * 60)

print(f"Name : {name}  -> Data Type : {type(name)}\n")

print(f"Roll Number : {roll_number} -> Data Type : {type(roll_number)}\n")

print(f"Age : {age} -> Data Type : {type(age)}\n")

print(f"GPA : {gpa} -> Data Type : {type(gpa)}\n")

print(f"Subjects : {subjects} -> Data Type : {type(subjects)}\n")

print(f"Grades : {grades} -> Data Type : {type(grades)}\n")

average_grade = sum(grades) / len(grades)
print(f"Average Grade : {average_grade} -> Data Type: {type(average_grade)}\n")

print(f"Address : {Address} -> Data Type : {type(Address)}\n")

print(f"IS Student Active : {is_active} -> Data Type : {type(is_active)}\n \nIS Student Graduated : {is_graduated} -> Data Type : {type(is_graduated)}\n")

print(f"Student Courses : {courses} -> Data Type : {type(courses)}\n")

print(f"Encoded Name : {encoded_name} -> Data Type : {type(encoded_name)}\n")

print(f"Modified Data : {modified_data} -> Data Type : {type(modified_data)}\n")

list_ids = list(student_Ids)
print(f"Student IDS : {list_ids} -> Data Type : {type(list_ids)}\n")

student_record = {
    "name" : "Ahmed Ali",
    "age"  : 22,
    "roll_number" : 101
}

print(f"Student Record : {student_record} -> Data Type : {type(student_record)}\n")

# frozenset
batch_info = frozenset({"Batch: 2024", "Section: A", "Student_ID: 101"})
print(f"Batch Info : {batch_info} -> Data Type : {type(batch_info)}")

# memoryview
encoded_name = b'Ahmed Ali'
name_view = memoryview(encoded_name)
print(f"Memory View : {name_view} -> Data Type : {type(name_view)}")


print("\n" + "="  * 60)
print("\n...................STUDENT MANAGEMENT SYSTEM\n...................PROGRAM COMPLETED SUCCESSFULLY!")
print("\n" + "="  * 60)
# Out:
# ...
#
# ...................STUDENT COMPLETE PROFILE
#
# ...
# Name : Ahmed Ali  -> Data Type : <class 'str'>
#
# Roll Number : 101 -> Data Type : <class 'int'>
#
# Age : 22 -> Data Type : <class 'int'>
#
# GPA : 3.75 -> Data Type : <class 'float'>
#
# Subjects : ['Math', 'Physics', 'CS', 'English'] -> Data Type : <class 'list'>
#
# Grades : [85, 90, 88, 78] -> Data Type : <class 'list'>
#
# Average Grade : 85.25 -> Data Type: <class 'float'>
#
# Address : ('House 10', 'Street 5', 'Karachi', 'Pakistan') -> Data Type : <class 'tuple'>
#
# IS Student Active : True -> Data Type : <class 'bool'>
#
# IS Student Graduated : False -> Data Type : <class 'bool'>
#
# Student Courses : {'Machine Learning', 'Data Science', 'AI', 'Python'} -> Data Type : <class 'set'>
#
# Encoded Name : b'Ali Ahmed' -> Data Type : <class 'bytes'>
#
# Modified Data : bytearray(b'Learner Data') -> Data Type : <class 'bytearray'>
#
# Student IDS : [101, 106] -> Data Type : <class 'list'>
#
# ...
